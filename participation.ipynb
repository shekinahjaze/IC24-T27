# %%
# Sub question 1

# libraries we're using

import pandas as pd
import datetime
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# Looking for how many total participants for all years of the program
df = pd.read_csv('Data_Level3_GreenTerp - Cleaned.csv')

#checking out communication
access_methods = df['Form_Access'].value_counts()
formaccessgraph = access_methods.plot.barh(x='Form Access',y='count',width=0.5,color='mediumpurple')
formaccessgraph.set_title('Form Access Methods')
formaccessgraph.set_xlabel('Where People Accessed the Form')
formaccessgraph.set_ylabel('Count')
# Out:
# /tmp/ipykernel_2838052/2202098718.py:12: DtypeWarning: Columns (25,26,37,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data_Level3_GreenTerp - Cleaned.csv')
# Text(0, 0.5, 'Count')
